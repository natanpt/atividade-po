# %% [markdown]
# # Solução — VRP Pickup & Delivery (exemplo)
#
# Notebook mínimo que carrega `solver.py` e executa o exemplo em `data/data.json`.

# %%
import json
from pathlib import Path
from solver import create_data_model_from_json, solve

data = create_data_model_from_json('data/data.json')
print('Dados carregados:')
print(json.dumps(data, indent=2))
print('\nTentando resolver (requer ortools instalado localmente)...')
try:
    solve(data)
except Exception as e:
    print('Erro ao rodar solver:', e)
